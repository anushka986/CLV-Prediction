# %% [markdown]
# ## Importing Libraries

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Reading Files

# %%
#Reading csv files
df1 = pd.read_csv('data/olist_customers_dataset.csv')
df2 = pd.read_csv('data/olist_order_items_dataset.csv')
df3 = pd.read_csv('data/olist_order_payments_dataset.csv.zip')
df4 = pd.read_csv('data/olist_order_reviews_dataset.csv')
df5 = pd.read_csv('data/olist_orders_dataset.csv.zip')
df6 = pd.read_csv('data/olist_products_dataset.csv.zip')
df7 = pd.read_csv('data/olist_sellers_dataset.csv')
df8 = pd.read_csv('data/product_category_name_translation.csv')

# %%
#Columns in different dataframes
for name, df in zip(['customers_dataset','order_items_dataset', 'order_payments_dataset', 'order_reviews_dataset', 'orders_dataset.csv', 'products_dataset', 'sellers_dataset', "product_category_name_translation"], [df1, df2, df3, df4, df5, df6, df7, df8]):
    print(f"--- columns from {name} ---")
    display(df.columns)
    print("\n")
# Out:
# --- columns from customers_dataset ---
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')
# --- columns from order_items_dataset ---
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')
# --- columns from order_payments_dataset ---
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')
# --- columns from order_reviews_dataset ---
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')
# --- columns from orders_dataset.csv ---
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')
# --- columns from products_dataset ---
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')
# --- columns from sellers_dataset ---
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')
# --- columns from product_category_name_translation ---
# Index(['product_category_name', 'product_category_name_english'], dtype='object')

# %%
#Displaying different csv files
for name, df in zip(['customers_dataset', 'order_items_dataset', 'order_payments_dataset', 'order_reviews_dataset', 'orders_dataset.csv', 'products_dataset', 'sellers_dataset', "product_category_name_translation"], [df1, df2, df3, df4, df5, df6, df7, df8]):
    print(f"--- Sample from {name} ---")
    display(df.sample(5))
    print("\n")
# Out:
# --- Sample from customers_dataset ---
#                             customer_id                customer_unique_id  \
# 36496  bebb261717d5fd18d378c249c396f6e5  05fb25843c4048d1ce40611d11966278
# 75390  f98d61da171a77960b2fdac4e68f3e98  4f43c0c423501c277165c4a8b756a354
# 81739  49a6ae8a95c6a78d90945b983ab1ecfc  fb7e29c65321441231990afc201c1b14
# 4134   a049003658eecf3b1d87246e326b3eb8  9db51925992833f0528f9dd55a77f204
# 58604  5c965d68ec3a145629e5ae44d82ee15d  e9f972b3f457a8ee43154af187aada14
#
#        customer_zip_code_prefix   customer_city customer_state
# 36496                     96055         pelotas             RS
# 75390                     87050         maringa             PR
# 81739                      4107       sao paulo             SP
# 4134                       7122       guarulhos             SP
# 58604                     30494  belo horizonte             MG
# --- Sample from order_items_dataset ---
#                                order_id  order_item_id  \
# 77295  aff48f2bfd2432bf92264b9308c424c3              1
# 13269  1e1f2f647008bb63f8fb6cfe18d64467              2
# 15691  23e3e258cb0914459e129f704d04733f              1
# 27501  3e927dfcc405632ef96885c77e6e5d83              1
# 85325  c1ddb9a2ec3bae0156fed0df64910447              1
#
#                              product_id                         seller_id  \
# 77295  20a56bb6cee7a1b8e02e245e637e1b8b  1f1bb1f0859883505541bdd6606193e5
# 13269  266bc9a69487d12f125e4af1b5da3d32  e333046ce6517bd8bb510291d44f0130
# 15691  8c0794180bc059d1af097905d7352cfa  4ba52dfeba874da5b9ee7b17c7494f04
# 27501  be3b8f91ced393f1ce60aacfb6a04c1d  46dc3b2cc0980fb8ec44634e21d2718e
# 85325  609b1b50202d276e56b2468006fa82aa  609e1a9a6c2539919b8205cf7c4e6ff0
#
#        shipping_limit_date   price  freight_value
# 77295  2017-07-06 01:50:15  349.99          14.79
# 13269  2017-12-29 02:51:16  119.00          25.67
# 15691  2017-09-19 21:44:43   99.00          25.14
# 27501  2017-10-17 18:35:42  239.99          17.93
# 85325  2018-03-27 06:48:03   73.90          23.10
# --- Sample from order_payments_dataset ---
#                                order_id  payment_sequential payment_type  \
# 62826  608d2b1247d371f22cbfa16713c82786                   1  credit_card
# 8987   b4507f69b71b51c75fbdbea7912ee840                   1  credit_card
# 32185  02b57c07010db3ded50936152756a6e8                   1  credit_card
# 49534  2301c13c9dc02b9c8d61919206e15e1c                   1  credit_card
# 55928  2130b83c315c16dd6afd6c742c6ae4a2                   1       boleto
#
#        payment_installments  payment_value
# 62826                     1          37.38
# 8987                      3          70.74
# 32185                     1         116.85
# 49534                     9          95.70
# 55928                     1         864.69
# --- Sample from order_reviews_dataset ---
#                               review_id                          order_id  \
# 34572  a01e7a219790c5e6963329a5138e93c4  1aef7a15aff34d2305b0e6994acd680b
# 55584  1461f6f113cbf253213414297776202b  9df4de8d3f1b15175f64dcfce276ee9b
# 14217  10bab0d7e7b5e600f73d8023b8d35f1c  924aa21372f93d04910e55caf9237b00
# 23521  a2847c331a9fccf9c9ad1822ee4a6d38  61fca91868781e2844bebf0ba3129950
# 47186  aff636c5cbff18f20a9d8b5786733325  5829e8dbf7adce16a91e4ba7e8c1e4e0
#
#        review_score    review_comment_title  \
# 34572             1  Cor do produto errada
# 55584             5                     NaN
# 14217             3                     NaN
# 23521             5                     NaN
# 47186             5                     NaN
#
#                                   review_comment_message review_creation_date  \
# 34572  Muita falta de atenção, pedi as toalhas pretas...  2018-06-30 00:00:00
# 55584                            Nota 10 no atendimento.  2017-03-22 00:00:00
# 14217                                                NaN  2018-04-14 00:00:00
# 23521                                                NaN  2018-03-13 00:00:00
# 47186                                                NaN  2017-09-28 00:00:00
#
#       review_answer_timestamp
# 34572     2018-07-03 10:18:21
# 55584     2017-03-25 20:44:11
# 14217     2018-04-15 15:06:16
# 23521     2018-03-17 22:29:06
# 47186     2017-09-29 00:33:04
# --- Sample from orders_dataset.csv ---
#                                order_id                       customer_id  \
# 95497  d26bc24224fef3d3b81a759802c26434  75e0bfb1c7701f6b53354ee10aa4268f
# 19334  fcc16b06bc5d641f05d936cc17e6be7f  c29c163d00335ad9470704acf3946544
# 37687  1a8549fdcb090e418620dd6b7bc7ca10  a1beb47c601965fd113716b0947ab37c
# 61126  5dc415d2a18c5bf06c2525fae14fb537  6f8f59c663734b3f188aba68f54342c3
# 85749  030aeef4719e9d33e0c39bd00a9a14be  b33f0975ea69aae6fac18326ac5bfb0b
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 95497    delivered      2017-10-22 18:07:06  2017-10-22 18:14:31
# 19334    delivered      2017-09-11 17:07:19  2017-09-11 17:35:30
# 37687    delivered      2018-08-17 12:23:58  2018-08-17 12:50:10
# 61126    delivered      2018-01-02 13:08:31  2018-01-02 13:16:26
# 85749    delivered      2017-06-30 19:24:36  2017-07-01 19:35:09
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 95497          2017-10-24 20:47:40           2017-11-03 20:42:35
# 19334          2017-09-13 17:35:12           2017-09-22 19:43:02
# 37687          2018-08-20 07:04:00           2018-08-27 15:10:57
# 61126          2018-01-24 18:09:24           2018-01-28 13:13:23
# 85749          2017-07-03 14:59:32           2017-07-18 14:12:02
#
#       order_estimated_delivery_date
# 95497           2017-11-09 00:00:00
# 19334           2017-10-02 00:00:00
# 37687           2018-09-04 00:00:00
# 61126           2018-02-02 00:00:00
# 85749           2017-07-13 00:00:00
# --- Sample from products_dataset ---
#                              product_id product_category_name  \
# 21825  3e1cec0f5b7ca2da3e6de97f6e92fd4b      moveis_decoracao
# 30366  36bd3e4daa4604d112f17dccd24ee59e             telefonia
# 24128  e45976e9ff4d139ed0e9bf83abeb5c80       cama_mesa_banho
# 9418   3f27ac8e699df3d300ec4a5d8c5cf0b2        consoles_games
# 14755  d3ce671d83f4434fbe5a05ff93427ef0             telefonia
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 21825                 60.0                       320.0                 7.0
# 30366                 48.0                       419.0                 2.0
# 24128                 58.0                       226.0                 1.0
# 9418                  37.0                      1172.0                 2.0
# 14755                 33.0                       580.0                 2.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 21825            5950.0               39.0               19.0
# 30366             150.0               17.0                8.0
# 24128            1700.0               40.0                7.0
# 9418              200.0               16.0                5.0
# 14755             100.0               16.0                3.0
#
#        product_width_cm
# 21825              48.0
# 30366              14.0
# 24128              30.0
# 9418               12.0
# 14755              11.0
# --- Sample from sellers_dataset ---
#                              seller_id  seller_zip_code_prefix  \
# 2563  7238a95bb63ef7e498389fb863b834a1                   13487
# 252   f88adb15807168d3c43d71021090ce4a                   13660
# 1327  b18871c324516afa228a13e8f1ef0ae9                    4186
# 1016  c7a0a13cbcf29d5ce51c8f80afdc0b89                   89170
# 2592  6601ee6383e7f452be71929f8de48bbb                   14027
#
#          seller_city seller_state
# 2563         limeira           SP
# 252   porto ferreira           SP
# 1327       sao paulo           SP
# 1016      laurentino           SC
# 2592  ribeirao pretp           SP
# --- Sample from product_category_name_translation ---
#       product_category_name product_category_name_english
# 42              moveis_sala         furniture_living_room
# 16       ferramentas_jardim                  garden_tools
# 28  fashion_roupa_masculina         fashion_male_clothing
# 10        alimentos_bebidas                    food_drink
# 29                 pet_shop                      pet_shop

# %% [markdown]
# ## Merging Files

# %%
##Merging all columns of all files(except Geolocation file)
orders_customers = pd.merge(df5, df1, on='customer_id', how='left')
order_items_products = pd.merge(df2, df6, on='product_id', how='left')
order_items_products_sellers = pd.merge(order_items_products, df7, on='seller_id', how='left')
orders_items_products_sellers_customers = pd.merge(orders_customers, order_items_products_sellers, on='order_id', how='left')
merged_df = pd.merge(orders_items_products_sellers_customers, df4, on='order_id', how='left')
merged_df = pd.merge(merged_df, df5, on='order_id', how='left')

merged_df = pd.merge(merged_df, df8, on='product_category_name', how='left')

# Geolocation data not merged

print("Merged Dataset Shape: ", merged_df.shape)
print("Columns\n", merged_df.columns)
display(merged_df.sample(5))
# Out:
# Merged Dataset Shape:  (114092, 43)
# Columns
#  Index(['order_id', 'customer_id_x', 'order_status_x',
#        'order_purchase_timestamp_x', 'order_approved_at_x',
#        'order_delivered_carrier_date_x', 'order_delivered_customer_date_x',
#        'order_estimated_delivery_date_x', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'customer_id_y',
#        'order_status_y', 'order_purchase_timestamp_y', 'order_approved_at_y',
#        'order_delivered_carrier_date_y', 'order_delivered_customer_date_y',
#        'order_estimated_delivery_date_y', 'product_category_name_english'],
#       dtype='object')
#                                 order_id                     customer_id_x  \
# 101016  c327bf79ca9f0099dd58157ec2b71839  6e2243e81dfbcf77269277d8b90834ed
# 49562   777f09795a87e5598924d1f7090deeb1  39c74e07d34944b5be0c87dc592e9882
# 57060   8976430d1df174a9bce201c4e859d921  710c1f2c83705274fbd85f1cc9cd1a0f
# 43783   156d020e7c34fa12b2b61a68ba9c7c0e  7128153a5176fa37b2c282b24cea3119
# 77376   fccbac503695b663355702609c925bdc  4f7d9e4445d5919ca479fd6859374094
#
#        order_status_x order_purchase_timestamp_x  order_approved_at_x  \
# 101016      delivered        2018-06-13 20:56:31  2018-06-13 21:20:37
# 49562       delivered        2018-08-10 15:03:50  2018-08-10 15:15:12
# 57060       delivered        2018-04-14 18:48:26  2018-04-14 19:10:59
# 43783       delivered        2017-07-02 14:22:28  2017-07-02 14:35:57
# 77376       delivered        2018-06-19 15:26:19  2018-06-20 10:21:32
#
#        order_delivered_carrier_date_x order_delivered_customer_date_x  \
# 101016            2018-06-14 13:50:00             2018-06-15 17:11:02
# 49562             2018-08-13 14:53:00             2018-08-15 20:58:35
# 57060             2018-04-17 14:19:31             2018-04-21 15:14:49
# 43783             2017-07-03 15:18:02             2017-07-07 19:19:43
# 77376             2018-06-20 14:29:00             2018-07-04 21:48:33
#
#        order_estimated_delivery_date_x                customer_unique_id  \
# 101016             2018-06-25 00:00:00  02aff8daa5b3527989a29500ff1e8e10
# 49562              2018-08-27 00:00:00  150efee9847adcb0a932c4d342920f16
# 57060              2018-05-23 00:00:00  d1484b34e362c48002d3ee703d5eb89d
# 43783              2017-07-17 00:00:00  0f1e4786bddd707cfa51e4f45668dda9
# 77376              2018-07-17 00:00:00  98eef1a36389d4148039ece41431831a
#
#         customer_zip_code_prefix  ... review_creation_date  \
# 101016                      9530  ...  2018-06-16 00:00:00
# 49562                      35020  ...  2018-08-16 00:00:00
# 57060                      20261  ...  2018-04-22 00:00:00
# 43783                       5878  ...  2017-07-08 00:00:00
# 77376                      11668  ...  2018-07-05 00:00:00
#
#        review_answer_timestamp                     customer_id_y  \
# 101016     2018-06-18 21:47:10  6e2243e81dfbcf77269277d8b90834ed
# 49562      2018-08-17 12:09:19  39c74e07d34944b5be0c87dc592e9882
# 57060      2018-04-22 21:59:37  710c1f2c83705274fbd85f1cc9cd1a0f
# 43783      2017-07-11 22:26:51  7128153a5176fa37b2c282b24cea3119
# 77376      2018-07-10 14:02:22  4f7d9e4445d5919ca479fd6859374094
#
#        order_status_y order_purchase_timestamp_y  order_approved_at_y  \
# 101016      delivered        2018-06-13 20:56:31  2018-06-13 21:20:37
# 49562       delivered        2018-08-10 15:03:50  2018-08-10 15:15:12
# 57060       delivered        2018-04-14 18:48:26  2018-04-14 19:10:59
# 43783       delivered        2017-07-02 14:22:28  2017-07-02 14:35:57
# 77376       delivered        2018-06-19 15:26:19  2018-06-20 10:21:32
#
#         order_delivered_carrier_date_y  order_delivered_customer_date_y  \
# 101016             2018-06-14 13:50:00              2018-06-15 17:11:02
# 49562              2018-08-13 14:53:00              2018-08-15 20:58:35
# 57060              2018-04-17 14:19:31              2018-04-21 15:14:49
# 43783              2017-07-03 15:18:02              2017-07-07 19:19:43
# 77376              2018-06-20 14:29:00              2018-07-04 21:48:33
#
#        order_estimated_delivery_date_y  product_category_name_english
# 101016             2018-06-25 00:00:00                 sports_leisure
# 49562              2018-08-27 00:00:00       fashion_bags_accessories
# 57060              2018-05-23 00:00:00                  health_beauty
# 43783              2017-07-17 00:00:00                 sports_leisure
# 77376              2018-07-17 00:00:00          computers_accessories
#
# [5 rows x 43 columns]

# %%
#Merging specific columns of different files
order_data = df5.merge(df2, on='order_id') \
                   .merge(df3, on='order_id') \
                   .merge(df1, on='customer_id') \
                   .merge(df4[['order_id', 'review_score']], on='order_id', how='left') \
                   .merge(df6[['product_id', 'product_category_name']], on='product_id', how='left') \
                   .merge(df8, on='product_category_name', how='left')


# Geolocation data not merged

order_data = order_data.drop('product_category_name', axis=1) #dropping Portuguese product name(keeping English name)

#displaying
display(order_data.shape)
display(order_data.columns)
display(order_data.sample(5))

#order details(id,status,purchase date, approved date, delivery dates,product id, shipping date,price,freight value)
#customer details(id,zip_code,city,state),seller(id,) product etails(id,category_name)
#payement details(payment type,installments,vaue,sequential)
# Out:
# (118307, 24)
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'review_score', 'product_category_name_english'],
#       dtype='object')
#                                 order_id                       customer_id  \
# 67104   31842de63b28390ef7b35e9b7c4a94a3  f92b90bf5a014b8e6da12f110bbc2bb8
# 98129   94de210268ddadb6c8e523a716f96164  68d71b7a75306be42e90795009f2a8cc
# 66661   dc8c9fb3edc11055d2fa5198744dff2b  089d1516887ddca8fe02ef9df9fe1e2a
# 108062  ef2d1b5b5f1fc3ea70338bb4c64f0129  a05f2d3e857bcfada74c1156e873049d
# 114908  e5d3a9fd67a092461d0a4e3feb145fb5  dcca41a026a2c9326ed70adf39220274
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 67104     delivered      2017-11-04 21:28:16  2017-11-07 07:30:28
# 98129     delivered      2017-10-11 12:55:32  2017-10-11 13:07:13
# 66661     delivered      2018-05-07 11:43:04  2018-05-09 02:54:17
# 108062    delivered      2018-08-15 16:24:12  2018-08-17 03:10:22
# 114908   processing      2017-12-24 13:33:13  2017-12-27 04:07:00
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 67104           2017-11-07 22:11:23           2017-11-10 18:37:53
# 98129           2017-10-13 15:55:53           2017-10-16 21:19:22
# 66661           2018-05-10 09:16:00           2018-05-15 22:34:44
# 108062          2018-08-17 12:05:00           2018-08-28 19:52:12
# 114908                          NaN                           NaN
#
#        order_estimated_delivery_date  order_item_id  \
# 67104            2017-11-27 00:00:00              1
# 98129            2017-10-24 00:00:00              1
# 66661            2018-05-28 00:00:00              1
# 108062           2018-09-17 00:00:00              1
# 114908           2018-01-19 00:00:00              1
#
#                               product_id  ... payment_sequential payment_type  \
# 67104   bd6e8cf9fe4122c385da2bcb9f979d5d  ...                  1       boleto
# 98129   e2c3ed9aaddfd2312a6a5fe9b3ddadd3  ...                  1  credit_card
# 66661   7a10781637204d8d10485c71a6108a2e  ...                  1       boleto
# 108062  3fbc0ef745950c7932d5f2a446189725  ...                  1       boleto
# 114908  530a9cb93b8b670336305e39f24a68d2  ...                  1       boleto
#
#         payment_installments  payment_value                customer_unique_id  \
# 67104                      1          97.37  dec0b0af1827fb725bf3a9d98063d2b4
# 98129                      5         104.03  589018d1e27d800dacec0dff51931ab3
# 66661                      1         199.00  250ff4b596100260ab4631ee13fa63b8
# 108062                     1          85.98  b536a0996ded58521eb555ee14e57413
# 114908                     1          54.84  5fd4bfd3fe98adf62ac641f0459dc961
#
#        customer_zip_code_prefix         customer_city  customer_state  \
# 67104                     13473             americana              SP
# 98129                     23059        rio de janeiro              RJ
# 66661                     17600                  tupa              SP
# 108062                     8051             sao paulo              SP
# 114908                     6852  itapecerica da serra              SP
#
#        review_score  product_category_name_english
# 67104           1.0                      telephony
# 98129           5.0                           toys
# 66661           5.0                  watches_gifts
# 108062          5.0                  health_beauty
# 114908          1.0          computers_accessories
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Data Cleaning

# %%
order_data.drop_duplicates(inplace=True,ignore_index=True)
order_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117888 entries, 0 to 117887
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117888 non-null  object
#  1   customer_id                    117888 non-null  object
#  2   order_status                   117888 non-null  object
#  3   order_purchase_timestamp       117888 non-null  object
#  4   order_approved_at              117873 non-null  object
#  5   order_delivered_carrier_date   116636 non-null  object
#  6   order_delivered_customer_date  115308 non-null  object
#  7   order_estimated_delivery_date  117888 non-null  object
#  8   order_item_id                  117888 non-null  int64
#  9   product_id                     117888 non-null  object
#  10  seller_id                      117888 non-null  object
#  11  shipping_limit_date            117888 non-null  object
#  12  price                          117888 non-null  float64
#  13  freight_value                  117888 non-null  float64
#  14  payment_sequential             117888 non-null  int64
#  15  payment_type                   117888 non-null  object
#  16  payment_installments           117888 non-null  int64
#  17  payment_value                  117888 non-null  float64
#  18  customer_unique_id             117888 non-null  object
#  19  customer_zip_code_prefix       117888 non-null  int64
#  20  customer_city                  117888 non-null  object
#  21  customer_state                 117888 non-null  object
#  22  review_score                   116910 non-null  float64
#  23  product_category_name_english  116160 non-null  object
# dtypes: float64(4), int64(4), object(16)
# memory usage: 21.6+ MB

# %%
order_data.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1252
# order_delivered_customer_date    2580
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# review_score                      978
# product_category_name_english    1728
# dtype: int64

# %% [markdown]
# ##### Cleaning datetime columns

# %%
#Converting data type of date col from object to datetime
date_columns = [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date',
    'shipping_limit_date',
]

for col in date_columns:
    order_data[col] = pd.to_datetime(order_data[col], errors='coerce')

order_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117888 entries, 0 to 117887
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117888 non-null  object
#  1   customer_id                    117888 non-null  object
#  2   order_status                   117888 non-null  object
#  3   order_purchase_timestamp       117888 non-null  datetime64[ns]
#  4   order_approved_at              117873 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   116636 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115308 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  117888 non-null  datetime64[ns]
#  8   order_item_id                  117888 non-null  int64
#  9   product_id                     117888 non-null  object
#  10  seller_id                      117888 non-null  object
#  11  shipping_limit_date            117888 non-null  datetime64[ns]
#  12  price                          117888 non-null  float64
#  13  freight_value                  117888 non-null  float64
#  14  payment_sequential             117888 non-null  int64
#  15  payment_type                   117888 non-null  object
#  16  payment_installments           117888 non-null  int64
#  17  payment_value                  117888 non-null  float64
#  18  customer_unique_id             117888 non-null  object
#  19  customer_zip_code_prefix       117888 non-null  int64
#  20  customer_city                  117888 non-null  object
#  21  customer_state                 117888 non-null  object
#  22  review_score                   116910 non-null  float64
#  23  product_category_name_english  116160 non-null  object
# dtypes: datetime64[ns](6), float64(4), int64(4), object(10)
# memory usage: 21.6+ MB

# %%
#Removing time from columns 
order_data['ord_purchase_date']=order_data['order_purchase_timestamp'].dt.date
order_data['ord_approved_date']=order_data['order_approved_at'].dt.date
order_data['ord_carrier_date']=order_data['order_delivered_carrier_date'].dt.date
order_data['ord_delivery_customer_date']=order_data['order_delivered_customer_date'].dt.date
order_data['est_ord_deliver_date']=order_data['order_estimated_delivery_date'].dt.date
order_data['ord_shipping_date']=order_data['shipping_limit_date'].dt.date
order_data.drop(columns=date_columns,inplace=True)

# %%
#Converting data type of date col from object to datetime
date_column = [
    'ord_purchase_date',
    'ord_approved_date',
    'ord_carrier_date',
    'ord_delivery_customer_date',
    'est_ord_deliver_date',
    'ord_shipping_date',
]

for col in date_column:
    order_data[col] = pd.to_datetime(order_data[col], errors='coerce')

order_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117888 entries, 0 to 117887
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117888 non-null  object
#  1   customer_id                    117888 non-null  object
#  2   order_status                   117888 non-null  object
#  3   order_item_id                  117888 non-null  int64
#  4   product_id                     117888 non-null  object
#  5   seller_id                      117888 non-null  object
#  6   price                          117888 non-null  float64
#  7   freight_value                  117888 non-null  float64
#  8   payment_sequential             117888 non-null  int64
#  9   payment_type                   117888 non-null  object
#  10  payment_installments           117888 non-null  int64
#  11  payment_value                  117888 non-null  float64
#  12  customer_unique_id             117888 non-null  object
#  13  customer_zip_code_prefix       117888 non-null  int64
#  14  customer_city                  117888 non-null  object
#  15  customer_state                 117888 non-null  object
#  16  review_score                   116910 non-null  float64
#  17  product_category_name_english  116160 non-null  object
#  18  ord_purchase_date              117888 non-null  datetime64[ns]
#  19  ord_approved_date              117873 non-null  datetime64[ns]
#  20  ord_carrier_date               116636 non-null  datetime64[ns]
#  21  ord_delivery_customer_date     115308 non-null  datetime64[ns]
#  22  est_ord_deliver_date           117888 non-null  datetime64[ns]
#  23  ord_shipping_date              117888 non-null  datetime64[ns]
# dtypes: datetime64[ns](6), float64(4), int64(4), object(10)
# memory usage: 21.6+ MB

# %% [markdown]
# ##### EDA

# %%
#differentiating col as categorical, numerical, datetime columns
categorical_col = [col for col in order_data.columns if order_data[col].dtype == 'object']
datetime_col = [col for col in order_data.columns if order_data[col].dtype == 'datetime64[ns]']
numerical_col = [col for col in order_data.columns if order_data[col].dtype != 'object' and order_data[col].dtype != 'datetime64[ns]']

# %%
order_data[categorical_col].describe()
# Out:
#                                 order_id                       customer_id  \
# count                             117888                            117888
# unique                             98665                             98665
# top     895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# freq                                  63                                63
#
#        order_status                        product_id  \
# count        117888                            117888
# unique            7                             32951
# top       delivered  aca2eb7d00ea1a7b8ebd4e68314663af
# freq         115309                               536
#
#                                seller_id payment_type  \
# count                             117888       117888
# unique                              3095            4
# top     4a3ca9315b744ce9f8e9374361493884  credit_card
# freq                                2148        86962
#
#                       customer_unique_id customer_city customer_state  \
# count                             117888        117888         117888
# unique                             95419          4110             27
# top     9a736b248f67d166d2fbb006bcb877c3     sao paulo             SP
# freq                                  75         18649          49676
#
#        product_category_name_english
# count                         116160
# unique                            71
# top                   bed_bath_table
# freq                           11898

# %% [markdown]
# ##### As unique value in order_id and customer id is same with same frequencies so we  can drop customer_id

# %%
order_data.drop(columns='customer_id',inplace=True)
order_data.drop(columns='customer_zip_code_prefix',inplace=True)

# %%
order_data[datetime_col].sample(5)
# Out:
#       ord_purchase_date ord_approved_date ord_carrier_date  \
# 32487        2017-08-12        2017-08-12       2017-08-14
# 89104        2018-03-13        2018-03-14       2018-03-19
# 68490        2018-02-24        2018-02-24       2018-02-27
# 59903        2017-05-20        2017-05-20       2017-05-23
# 12919        2017-11-24        2017-11-24       2017-11-29
#
#       ord_delivery_customer_date est_ord_deliver_date ord_shipping_date
# 32487                 2017-08-18           2017-09-05        2017-08-16
# 89104                 2018-04-06           2018-03-29        2018-03-20
# 68490                 2018-03-09           2018-03-23        2018-03-01
# 59903                 2017-05-31           2017-06-13        2017-05-25
# 12919                 2017-12-14           2017-12-22        2017-11-30

# %%
sns.histplot(order_data['price'], bins=50, kde = True)
plt.title('Distribution of Price')
plt.show()

# %%
sns.histplot(order_data['freight_value'], bins=50, kde = True)
plt.title('Distribution of Freight Value')
plt.show()

# %%
sns.countplot(order_data,x='customer_state')
order_data['customer_state'].value_counts()
#this of no use
# Out:
# customer_state
# SP    49676
# RJ    15381
# MG    13662
# RS     6506
# PR     5976
# SC     4306
# BA     4058
# DF     2487
# GO     2445
# ES     2341
# PE     1892
# CE     1555
# MT     1126
# PA     1118
# MS      848
# MA      846
# PB      639
# PI      573
# RN      570
# AL      459
# SE      397
# TO      339
# RO      286
# AM      171
# AC       95
# AP       84
# RR       52
# Name: count, dtype: int64

# %%
#dropping customer state and city
order_data.drop(columns='customer_state',inplace=True)
order_data.drop(columns='customer_city',inplace=True)

# %%
sns.countplot(order_data,x='payment_type')
# Out:
# <Axes: xlabel='payment_type', ylabel='count'>

# %%
sns.countplot(order_data,x='review_score')
# Out:
# <Axes: xlabel='review_score', ylabel='count'>

# %%
#sns.countplot(order_data,x='product_category_name_english')
order_data['product_category_name_english'].value_counts().plot(kind='pie')
# if we want to use this columns we need to group various products of same type .
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### New dataframe to find CLV

# %%
order_data['customer_unique_id'].value_counts()
# Out:
# customer_unique_id
# 9a736b248f67d166d2fbb006bcb877c3    75
# 6fbc7cdadbb522125f4b27ae9dee4060    38
# f9ae226291893fda10af7965268fb7f6    35
# 8af7ac63b2efbcbd88e5b11505e8098a    29
# 569aa12b73b5f7edeaa6f2a01603e381    26
#                                     ..
# cccd50988ef52de84f8ed4002fb28ab5     1
# b632c70b9c2c062dfacbad69e08f6563     1
# 2dee0e87b84b55e9879355315c11eb03     1
# f04534e01ef384f6f11113da312438a8     1
# 60350aa974b26ff12caad89e55993bd6     1
# Name: count, Length: 95419, dtype: int64

# %%
a=order_data.groupby('customer_unique_id')['order_id'].count()
b=order_data.groupby('customer_unique_id')['payment_value'].sum()
c=order_data.groupby('customer_unique_id')['price'].sum()
d=order_data.groupby('customer_unique_id')['freight_value'].sum()
e=order_data.groupby('customer_unique_id')['ord_purchase_date'].min()
f=order_data.groupby('customer_unique_id')['ord_purchase_date'].max()

# %%
z=pd.merge(a,b, on='customer_unique_id')
z=pd.merge(z,c, on='customer_unique_id')
z=pd.merge(z,d, on='customer_unique_id')
z=pd.merge(z,e, on='customer_unique_id')
z=pd.merge(z,f, on='customer_unique_id')

# %%
z.rename(columns = {'order_id':'Order count',
         'ord_purchase_date_x' : 'First Order Date',
         'ord_purchase_date_y' : 'Last Order Date'}, inplace = True)
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95419 entries, 0000366f3b9a7992bf8c76cfdf3221e2 to ffffd2657e2aad2907e67c3e9daecbeb
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order count       95419 non-null  int64
#  1   payment_value     95419 non-null  float64
#  2   price             95419 non-null  float64
#  3   freight_value     95419 non-null  float64
#  4   First Order Date  95419 non-null  datetime64[ns]
#  5   Last Order Date   95419 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(1)
# memory usage: 5.1+ MB

# %%
z.sample(10)
# Out:
#                                   Order count  payment_value   price  \
# customer_unique_id
# 3f8d6900f9761a6c9d65d9fd819bc38f            1          46.01   29.90
# cae0b155d09593a1d08b09e66b19c931            1          54.09   39.99
# 3e874b23b6b46a0a50dffce68e61a56b            1         160.23  114.97
# 54d0581e27042d4f305886d5469fc635            1         121.20   89.90
# 8586b13d284c943b1dad27ee45e1a423            1         162.57  102.62
# febec0d5d190519a8ec0e4beaa9172bd            1          81.82   69.00
# 8fde03547587c1e6f97d14148f422242            1         347.74  329.00
# 79dbcd2f36ded23128f0fb765613f137            1         119.79   99.90
# ea6f35445410a3f7e74c018be1642995            1         227.30  201.34
# 92da8bc27242469f90d1131d66d562b3            1          75.65   58.99
#
#                                   freight_value First Order Date  \
# customer_unique_id
# 3f8d6900f9761a6c9d65d9fd819bc38f          16.11       2017-11-24
# cae0b155d09593a1d08b09e66b19c931          14.10       2017-12-11
# 3e874b23b6b46a0a50dffce68e61a56b          45.26       2017-08-01
# 54d0581e27042d4f305886d5469fc635          31.30       2018-01-31
# 8586b13d284c943b1dad27ee45e1a423          59.95       2018-07-17
# febec0d5d190519a8ec0e4beaa9172bd          12.82       2017-12-12
# 8fde03547587c1e6f97d14148f422242          18.74       2017-07-20
# 79dbcd2f36ded23128f0fb765613f137          19.89       2018-08-01
# ea6f35445410a3f7e74c018be1642995          25.96       2018-02-27
# 92da8bc27242469f90d1131d66d562b3          16.66       2017-08-31
#
#                                  Last Order Date
# customer_unique_id
# 3f8d6900f9761a6c9d65d9fd819bc38f      2017-11-24
# cae0b155d09593a1d08b09e66b19c931      2017-12-11
# 3e874b23b6b46a0a50dffce68e61a56b      2017-08-01
# 54d0581e27042d4f305886d5469fc635      2018-01-31
# 8586b13d284c943b1dad27ee45e1a423      2018-07-17
# febec0d5d190519a8ec0e4beaa9172bd      2017-12-12
# 8fde03547587c1e6f97d14148f422242      2017-07-20
# 79dbcd2f36ded23128f0fb765613f137      2018-08-01
# ea6f35445410a3f7e74c018be1642995      2018-02-27
# 92da8bc27242469f90d1131d66d562b3      2017-08-31

# %% [markdown]
# ## Calculating Recency, Frequency, Customer's Tenure and Monetary Value

# %%
latest_date = z['Last Order Date'].max()
print("The last day of purchase in the dataset : ", latest_date)
# Out:
# The last day of purchase in the dataset :  2018-09-03 00:00:00

# %%
z['Recency'] = latest_date - z['Last Order Date']
z['Customer Tenure'] = latest_date - z['First Order Date']
z['Repeat Purchases'] = z['Order count'] - 1                  #Frequency
z['Monetary Value'] = z['payment_value'] / z['Order count']

# %%
z.sample(10)
# Out:
#                                   Order count  payment_value   price  \
# customer_unique_id
# 5624dec0a80e5d123f451b83ab841ee1            1          62.65   55.00
# 8aae1fe1241741cbc1deec6e29998065            1         117.97  104.90
# 5ac793e4672aebec868e5d3795fb02fc            1         285.78  269.99
# 65eb842bca2b9de966e0666e0ae4963a            1          25.13    6.90
# 6a316d035d582311678aa9697c9b31d2            1          43.27   24.99
# 83b202cf2259eaf8c5d738db40ea217e            1         136.75  109.90
# 30481e1a036ca07d9f53c0a3a160a72a            1          58.13   42.90
# 6d7c24825fd7ec8c73cf050a300ee9d2            1          90.88   69.90
# 3857428967edc9647b8af374c0d78dfb            1         822.07  772.20
# 37ae58e18d929c7d9b35cbde0e19ab1f            1         369.76  340.00
#
#                                   freight_value First Order Date  \
# customer_unique_id
# 5624dec0a80e5d123f451b83ab841ee1           7.65       2018-06-22
# 8aae1fe1241741cbc1deec6e29998065          13.07       2018-01-21
# 5ac793e4672aebec868e5d3795fb02fc          15.79       2017-10-07
# 65eb842bca2b9de966e0666e0ae4963a          18.23       2018-05-16
# 6a316d035d582311678aa9697c9b31d2          18.28       2018-06-22
# 83b202cf2259eaf8c5d738db40ea217e          26.85       2018-06-06
# 30481e1a036ca07d9f53c0a3a160a72a          15.23       2018-04-06
# 6d7c24825fd7ec8c73cf050a300ee9d2          20.98       2017-12-12
# 3857428967edc9647b8af374c0d78dfb          49.87       2018-02-04
# 37ae58e18d929c7d9b35cbde0e19ab1f          29.76       2018-01-16
#
#                                  Last Order Date  Recency Customer Tenure  \
# customer_unique_id
# 5624dec0a80e5d123f451b83ab841ee1      2018-06-22  73 days         73 days
# 8aae1fe1241741cbc1deec6e29998065      2018-01-21 225 days        225 days
# 5ac793e4672aebec868e5d3795fb02fc      2017-10-07 331 days        331 days
# 65eb842bca2b9de966e0666e0ae4963a      2018-05-16 110 days        110 days
# 6a316d035d582311678aa9697c9b31d2      2018-06-22  73 days         73 days
# 83b202cf2259eaf8c5d738db40ea217e      2018-06-06  89 days         89 days
# 30481e1a036ca07d9f53c0a3a160a72a      2018-04-06 150 days        150 days
# 6d7c24825fd7ec8c73cf050a300ee9d2      2017-12-12 265 days        265 days
# 3857428967edc9647b8af374c0d78dfb      2018-02-04 211 days        211 days
# 37ae58e18d929c7d9b35cbde0e19ab1f      2018-01-16 230 days        230 days
#
#                                   Repeat Purchases  Monetary Value
# customer_unique_id
# 5624dec0a80e5d123f451b83ab841ee1                 0           62.65
# 8aae1fe1241741cbc1deec6e29998065                 0          117.97
# 5ac793e4672aebec868e5d3795fb02fc                 0          285.78
# 65eb842bca2b9de966e0666e0ae4963a                 0           25.13
# 6a316d035d582311678aa9697c9b31d2                 0           43.27
# 83b202cf2259eaf8c5d738db40ea217e                 0          136.75
# 30481e1a036ca07d9f53c0a3a160a72a                 0           58.13
# 6d7c24825fd7ec8c73cf050a300ee9d2                 0           90.88
# 3857428967edc9647b8af374c0d78dfb                 0          822.07
# 37ae58e18d929c7d9b35cbde0e19ab1f                 0          369.76

# %%
z['Recency'].value_counts()
# Out:
# Recency
# 283 days    1133
# 282 days     483
# 280 days     388
# 281 days     374
# 28 days      367
#             ...
# 605 days       4
# 728 days       1
# 701 days       1
# 729 days       1
# 0 days         1
# Name: count, Length: 614, dtype: int64

# %%
sns.histplot(z['Recency'].dt.days, bins = 30, kde = True)
plt.show()

# %% [markdown]
# As the plot falls steeply after 300, we consider Recency greater than 300 as churned customers.

# %%
z['Is_Churned'] = (z['Recency'].dt.days > 300).astype(int)

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95419 entries, 0000366f3b9a7992bf8c76cfdf3221e2 to ffffd2657e2aad2907e67c3e9daecbeb
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order count       95419 non-null  int64
#  1   payment_value     95419 non-null  float64
#  2   price             95419 non-null  float64
#  3   freight_value     95419 non-null  float64
#  4   First Order Date  95419 non-null  datetime64[ns]
#  5   Last Order Date   95419 non-null  datetime64[ns]
#  6   Recency           95419 non-null  timedelta64[ns]
#  7   Customer Tenure   95419 non-null  timedelta64[ns]
#  8   Repeat Purchases  95419 non-null  int64
#  9   Monetary Value    95419 non-null  float64
#  10  Is_Churned        95419 non-null  int32
# dtypes: datetime64[ns](2), float64(4), int32(1), int64(2), timedelta64[ns](2)
# memory usage: 8.4+ MB
